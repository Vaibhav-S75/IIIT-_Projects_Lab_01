# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhav-S75/IIIT-_Projects_Lab_01/blob/main/Notebook_First_Lab_ML_Vaibhav_S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is First lab notebook of **Vaibhav Sakharwade CSE** GHRCE NGP  consisting all the questions asked in the module.

# %%
#Quetion 00
'''Write down 3-5 methods applicable to each data type. (Hint: extend, reverse, etc.)
ANS:- For *list its {append, insert, remove, sort}
*String {upper, lover, replace, split}
*Dictionaries {get, keys, values, items}
*Tuples {index, count, len}

# %%
#Quetion 01
def reverse_and_concatenate(A, B):
    reversed_A = A[::-1]
    result = reversed_A + B
    return result

string_A = "Hello"
string_B = "World"
result = reverse_and_concatenate(string_A, string_B)
print(result)
# Out:
# olleHWorld

# %%
#Quetion 02
def find_highest_working_female(work_hours, hourly_rate=20):
    max_hours = 0
    female_worker = None

    for name, hours, gender in work_hours:
        if gender == 'F' and hours > max_hours:
            max_hours = hours
            female_worker = name

    if female_worker:
        pay = max_hours * hourly_rate
        return f"The female who worked  most hours is {female_worker} with {max_hours} hours. She paid ${pay}."
    else:
        return "No female workers found."

work_hours = [('Abby', 100, 'F'), ('Billy', 400, 'M'), ('Cassie', 800, 'F'), ('Maggi', 600, 'F'), ('Alex', 500, 'M'), ('Raj', 225, 'M'), ('Penny', 920, 'F'), ('Ben', 300, 'M')]

result = find_highest_working_female(work_hours)
print(result)

# %%
#Quetion 03 A
import numpy as np

base_matrix = np.array([[1, 1], [2, 2]])

matrix = np.tile(base_matrix, (2, 2))

print(matrix)
# Out:
# [[1 1 1 1]
#  [2 2 2 2]
#  [1 1 1 1]
#  [2 2 2 2]]

# %%
#B
import numpy as np

matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])

if matrix1.shape[1] == matrix2.shape[0]:
    dot_product = np.dot(matrix1, matrix2)
    print("Dot Product Result:")
    print(dot_product)
else:
    print("Matrix dimensions are not compatible for dot product.")
# Out:
# Dot Product Result:
# [[19 22]
#  [43 50]]

# %%
#Import a image through drive
import numpy as np
import cv2
img = plt.imread("/content/VRS.jpg.png")

# %%
plt.imshow(img)
