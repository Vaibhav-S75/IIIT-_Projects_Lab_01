# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhav-S75/IIIT-_Projects_Lab_01/blob/main/Module_09_Lab03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Module 9: Neural Networks
#
# Lab 2: Using MLP for multiclass classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 248.97it/s]

# %% [markdown]
# Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# Experiment with the neural network architecture
#
# 1)Try changing the number of hidden layers.
#
# 2)Try changing the number of neurons in the hidden layer.
#
# 3)Try using a different activation function.
# Can you observe any changes?

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, activations
from tensorflow.keras.datasets import mnist

# Load and preprocess the data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Base Model
def create_base_model():
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 1: Change the number of hidden layers
def create_model_exp1(num_hidden_layers):
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(28, 28)))
    for _ in range(num_hidden_layers):
        model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))
    return model

# Experiment 2: Change the number of neurons in the hidden layer
def create_model_exp2(num_neurons):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(num_neurons, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Experiment 3: Use a different activation function
def create_model_exp3(activation_func):
    model = models.Sequential([
        layers.Flatten(input_shape=(28, 28)),
        layers.Dense(128, activation=activation_func),
        layers.Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate a given model
def train_and_evaluate(model):
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels))

# Base Model
print("Base Model:")
base_model = create_base_model()
train_and_evaluate(base_model)

# Experiment 1: Change the number of hidden layers
print("\nExperiment 1: Change the number of hidden layers")
for num_hidden_layers in [1, 2, 3]:
    print(f"\nNumber of hidden layers: {num_hidden_layers}")
    model_exp1 = create_model_exp1(num_hidden_layers)
    train_and_evaluate(model_exp1)

# Experiment 2: Change the number of neurons in the hidden layer
print("\nExperiment 2: Change the number of neurons in the hidden layer")
for num_neurons in [64, 128, 256]:
    print(f"\nNumber of neurons in the hidden layer: {num_neurons}")
    model_exp2 = create_model_exp2(num_neurons)
    train_and_evaluate(model_exp2)

# Experiment 3: Use a different activation function
print("\nExperiment 3: Use a different activation function")
activation_functions = ['relu', 'tanh', 'sigmoid']
for activation_func in activation_functions:
    print(f"\nActivation function: {activation_func}")
    model_exp3 = create_model_exp3(activation_func)
    train_and_evaluate(model_exp3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Base Model:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2597 - accuracy: 0.9263 - val_loss: 0.1356 - val_accuracy: 0.9603
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1131 - accuracy: 0.9672 - val_loss: 0.0970 - val_accuracy: 0.9697
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0794 - accuracy: 0.9763 - val_loss: 0.0890 - val_accuracy: 0.9730
# Epoch 4/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0601 - accuracy: 0.9818 - val_loss: 0.0767 - val_accuracy: 0.9763
# Epoch 5/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0474 - accuracy: 0.9848 - val_loss: 0.0827 - val_accuracy: 0.9743
#
# Experiment 1: Change the number of hidden layers
#
# Number of hidden layers: 1
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2618 - accuracy: 0.9251 - val_loss: 0.1354 - val_accuracy: 0.9590
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1185 - accuracy: 0.9651 - val_loss: 0.1012 - val_accuracy: 0.9699
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0836 - accuracy: 0.9750 - val_loss: 0.0937 - val_accuracy: 0.9698
# Epoch 4/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0617 - accuracy: 0.9812 - val_loss: 0.0757 - val_accuracy: 0.9769
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0463 - accuracy: 0.9859 - val_loss: 0.0784 - val_accuracy: 0.9769
#
# Number of hidden layers: 2
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2312 - accuracy: 0.9326 - val_loss: 0.1167 - val_accuracy: 0.9655
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0989 - accuracy: 0.9701 - val_loss: 0.0894 - val_accuracy: 0.9718
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0704 - accuracy: 0.9777 - val_loss: 0.0994 - val_accuracy: 0.9667
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0532 - accuracy: 0.9827 - val_loss: 0.0680 - val_accuracy: 0.9779
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0410 - accuracy: 0.9865 - val_loss: 0.0839 - val_accuracy: 0.9740
#
# Number of hidden layers: 3
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.2288 - accuracy: 0.9311 - val_loss: 0.1173 - val_accuracy: 0.9632
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1002 - accuracy: 0.9688 - val_loss: 0.1051 - val_accuracy: 0.9698
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0705 - accuracy: 0.9778 - val_loss: 0.0798 - val_accuracy: 0.9751
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0561 - accuracy: 0.9823 - val_loss: 0.0920 - val_accuracy: 0.9724
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0451 - accuracy: 0.9855 - val_loss: 0.0971 - val_accuracy: 0.9715
#
# Experiment 2: Change the number of neurons in the hidden layer
#
# Number of neurons in the hidden layer: 64
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3048 - accuracy: 0.9139 - val_loss: 0.1730 - val_accuracy: 0.9475
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1489 - accuracy: 0.9568 - val_loss: 0.1315 - val_accuracy: 0.9605
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1083 - accuracy: 0.9684 - val_loss: 0.1113 - val_accuracy: 0.9658
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0846 - accuracy: 0.9749 - val_loss: 0.0966 - val_accuracy: 0.9699
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0700 - accuracy: 0.9793 - val_loss: 0.0919 - val_accuracy: 0.9717
#
# Number of neurons in the hidden layer: 128
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2581 - accuracy: 0.9258 - val_loss: 0.1343 - val_accuracy: 0.9621
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1109 - accuracy: 0.9673 - val_loss: 0.0970 - val_accuracy: 0.9708
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0758 - accuracy: 0.9770 - val_loss: 0.0813 - val_accuracy: 0.9760
# Epoch 4/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0571 - accuracy: 0.9824 - val_loss: 0.0811 - val_accuracy: 0.9748
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0438 - accuracy: 0.9868 - val_loss: 0.0742 - val_accuracy: 0.9771
#
# Number of neurons in the hidden layer: 256
# Epoch 1/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2260 - accuracy: 0.9332 - val_loss: 0.1153 - val_accuracy: 0.9638
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0903 - accuracy: 0.9729 - val_loss: 0.0928 - val_accuracy: 0.9710
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0620 - accuracy: 0.9812 - val_loss: 0.0840 - val_accuracy: 0.9742
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0444 - accuracy: 0.9863 - val_loss: 0.0666 - val_accuracy: 0.9790
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0334 - accuracy: 0.9898 - val_loss: 0.0707 - val_accuracy: 0.9791
#
# Experiment 3: Use a different activation function
#
# Activation function: relu
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2557 - accuracy: 0.9264 - val_loss: 0.1273 - val_accuracy: 0.9620
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1110 - accuracy: 0.9669 - val_loss: 0.1000 - val_accuracy: 0.9693
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0765 - accuracy: 0.9766 - val_loss: 0.0808 - val_accuracy: 0.9736
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0567 - accuracy: 0.9826 - val_loss: 0.0805 - val_accuracy: 0.9746
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0436 - accuracy: 0.9865 - val_loss: 0.0740 - val_accuracy: 0.9771
#
# Activation function: tanh
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2860 - accuracy: 0.9176 - val_loss: 0.1647 - val_accuracy: 0.9514
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1366 - accuracy: 0.9596 - val_loss: 0.1185 - val_accuracy: 0.9649
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0931 - accuracy: 0.9723 - val_loss: 0.0923 - val_accuracy: 0.9728
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0680 - accuracy: 0.9803 - val_loss: 0.0804 - val_accuracy: 0.9758
# Epoch 5/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0520 - accuracy: 0.9845 - val_loss: 0.0773 - val_accuracy: 0.9767
#
# Activation function: sigmoid
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.3966 - accuracy: 0.8974 - val_loss: 0.2252 - val_accuracy: 0.9343
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1963 - accuracy: 0.9438 - val_loss: 0.1667 - val_accuracy: 0.9498
# Epoch 3/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.1447 - accuracy: 0.9581 - val_loss: 0.1353 - val_accuracy: 0.9599
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1121 - accuracy: 0.9676 - val_loss: 0.1134 - val_accuracy: 0.9662
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0909 - accuracy: 0.9739 - val_loss: 0.1069 - val_accuracy: 0.9674
